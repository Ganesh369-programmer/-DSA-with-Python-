# %%
import os
 
print(os.getcwd())
# Out:
# d:\Python Projects\DSA\modules_practice\library

# %%
#csv

import csv

with open('example.csv' , mode='w' , newline='') as file:
    write = csv.writer(file)
    write.writerow(['name' , 'age'])
    write.writerow(['Ganesh' , '20'])


with open('example.csv' , mode='r') as file:
    reader = csv.reader(file)

    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Ganesh', '20']

# %%
from datetime import datetime , timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-01-21 16:54:54.842237
# 2026-01-20 16:54:54.842237

# %%
## Time 

import time 

print(time.time())

time.sleep(2)

print(time.time())
# Out:
# 1768994825.5019345
# 1768994827.5044773

# %%
import re

pattern = r'\d+'

text = 'There are 1234 apples '
match = re.search(pattern , text)
print(match.group())
# Out:
# 1234
