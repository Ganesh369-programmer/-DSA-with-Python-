# %% [markdown]
# Example:
#
# Input: (1, 2, 3, 2, 1)
# Output: True
#
# Input: ('a', 'b', 'c', 'b', 'a')
# Output: True
#
# Input: (1, 2, 3, 4, 5)
# Output: False
#
# Input: ('x', 'y', 'z', 'x')
# Output: False
#
# Input: ('a',)
# Output: True

# %%
def is_palindromic_tuple(tup):
    # Your code goes here
    
    revese = tup[::-1]

    if tup == revese:
        return True
    else:
        return False

is_palindromic_tuple(('a', 'b', 'c', 'b', 'a'))
# Out:
# True
