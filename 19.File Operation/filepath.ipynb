# %%
new_dir = 'Package'

import os 
os.makedirs(new_dir)
print(f"Your new {new_dir} is created ")
# Out:
# Your new Package is created

# %%
items = os.listdir('.')
print(items)
# Out:
# ['example.bin', 'example.txt', 'fileoperation.ipynb', 'filepath.ipynb', 'Package']
