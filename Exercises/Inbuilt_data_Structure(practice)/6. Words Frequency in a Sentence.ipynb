# %%
def count_word_frequency(sentence):
    # Your code goes here
   
    s = sentence.split()

    d = { }
 
    # for i in s:
    #     if i in s:
    #         d[i] = d.get(i , 0) + 1

    for i in s:
        if i in d:
            d[i] += 1
        else:
            d[i] = 1

    return d

count_word_frequency("hello world hello")
# Out:
# {'hello': 2, 'world': 1}
