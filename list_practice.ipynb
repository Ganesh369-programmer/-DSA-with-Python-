# %% [markdown]
# #### Real-World Examples Using Lists in Python
# Lists are one of the most commonly used data structures in Python, thanks to their versatility and ease of use. Here are several practical examples that illustrate their use in real-world scenarios

# %% [markdown]
# ##### Example 1. Manage A To Do List
# - Create a To Do List To Keep Track OF Tasks

# %%
# Out:
# 2

# %%
to_do_list = ["Buy Groceries" , "Clean the house" , "Pay bills"]

##add the task
to_do_list.append("Schedulr Metteing")

def add_task(i):
    to_do_list.append(i)
    show()

def show():
    i = 0
    print("")
    print("")
    for x in to_do_list:
        
        print(f"{i} . {x}")
        i = i + 1

print("1 . Add the Task")
print("2 . Remove the Task")
print("3 . Display whole Task")
print("4 . Add tag as Important Task")
print("")
print("")
print("")




while True:
    choose = int(input("1 for add and 2 for remove"))
    if choose == 1:
        a = input('Add the Task')
        print("Successfully Added")
        add_task(a)


    if choose == 2:
        show()
        r = int(input("Enter the number for remove item "))
        del to_do_list[r]
        print("")
        print("Successfully Deleted ")
        show()

    if choose == 3:
        show()

    if choose == 4:
        None

    if choose == 0:
        break
# Out:
# 1 . Add the Task
# 2 . Remove the Task
# 3 . Display whole Task
#
#
#
#
#
# 0 . Buy Groceries
#
#
# 1 . Clean the house
#
#
# 2 . Pay bills
#
#
# 3 . Schedulr Metteing

# %% [markdown]
# ##### Example 2: Organizing Student Grades
# - Create a list to store and calculate average grades for students

# %%
# Organizing student grades
grades = [85, 92, 78, 90, 88]

# Adding a new grade
grades.append(95)

average_grade = sum(grades) / len(grades)
print(f"Average Grade : {average_grade: .2f}")

#finding the highest and lowest grades 
highest_grade = max(grades)
lowest_grade = min(grades)

print(f"Highest Grade : {highest_grade}")
print(f"Lowest Grade : {lowest_grade}")
# Out:
# Average Grade :  88.00
# Highest Grade : 95
# Lowest Grade : 78

# %% [markdown]
# ##### Example 3: Managing An Inventory
# - Use a list to manage inventory items in a store

# %%
inventory = ["apples", "bananas", "oranges", "grapes"]

#adding item
inventory.append("strawberry")

#removing the item 
inventory.remove("bananas")

#checking if an items 

item = "oranges"
if item in inventory:
    print(f"{item} are in stock")
else:
    print(f"{item} are out of stock")

#print the item 

print("")
for i in inventory:
    print(f"-{i}")
# Out:
# oranges are in stock
#
# -apples
# -oranges
# -grapes
# -strawberry
