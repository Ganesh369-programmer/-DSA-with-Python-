# %% [markdown]
# Example:
#
# Input: lst = [1, 2, 3, 4, 5]
# Output: [5, 4, 3, 2, 1]

# %%
def reverse_list(lst):
    # Your code goes here
    l = []
    for i in lst[::-1]:
        l.append(i)
        
    return l
